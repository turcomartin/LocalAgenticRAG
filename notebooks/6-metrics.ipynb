# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install ragas langchain_openai python-dotenv
# Out:
# Requirement already satisfied: ragas in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (0.1.14)
# Requirement already satisfied: langchain_openai in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (0.1.21)
# Requirement already satisfied: python-dotenv in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (1.0.1)
# Requirement already satisfied: numpy in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from ragas) (1.26.4)
# Requirement already satisfied: datasets in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from ragas) (2.21.0)
# Requirement already satisfied: tiktoken in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from ragas) (0.7.0)
# Requirement already satisfied: langchain in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from ragas) (0.2.14)
# Requirement already satisfied: langchain-core in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from ragas) (0.2.32)
# Requirement already satisfied: langchain-community in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from ragas) (0.2.12)
# Requirement already satisfied: openai>1 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from ragas) (1.40.6)
# Requirement already satisfied: pysbd>=0.3.4 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from ragas) (0.3.4)
# Requirement already satisfied: nest-asyncio in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from ragas) (1.6.0)
# Requirement already satisfied: appdirs in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from ragas) (1.4.4)
# Requirement already satisfied: PyYAML>=5.3 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from langchain-core->ragas) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from langchain-core->ragas) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from langchain-core->ragas) (0.1.93)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from langchain-core->ragas) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from langchain-core->ragas) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from langchain-core->ragas) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from langchain-core->ragas) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from openai>1->ragas) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from openai>1->ragas) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from openai>1->ragas) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from openai>1->ragas) (0.5.0)
# Requirement already satisfied: sniffio in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from openai>1->ragas) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from openai>1->ragas) (4.66.4)
# Requirement already satisfied: regex>=2022.1.18 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from tiktoken->ragas) (2024.5.15)
# Requirement already satisfied: requests>=2.26.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from tiktoken->ragas) (2.32.3)
# Requirement already satisfied: filelock in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from datasets->ragas) (3.15.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from datasets->ragas) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from datasets->ragas) (0.3.8)
# Requirement already satisfied: pandas in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from datasets->ragas) (2.2.2)
# Requirement already satisfied: xxhash in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from datasets->ragas) (3.5.0)
# Requirement already satisfied: multiprocess in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from datasets->ragas) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->ragas) (2024.6.1)
# Requirement already satisfied: aiohttp in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from datasets->ragas) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from datasets->ragas) (0.24.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from langchain->ragas) (2.0.31)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from langchain->ragas) (0.2.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from langchain-community->ragas) (0.6.7)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from aiohttp->datasets->ragas) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from aiohttp->datasets->ragas) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from aiohttp->datasets->ragas) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from aiohttp->datasets->ragas) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from aiohttp->datasets->ragas) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>1->ragas) (3.7)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (0.9.0)
# Requirement already satisfied: certifi in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>1->ragas) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>1->ragas) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>1->ragas) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core->ragas) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core->ragas) (3.10.6)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core->ragas) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core->ragas) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->ragas) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->ragas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from pandas->datasets->ragas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from pandas->datasets->ragas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from pandas->datasets->ragas) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets->ragas) (1.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/mrturco/miniconda3/envs/localrag/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->ragas) (1.0.0)

# %%
from langchain_ollama import ChatOllama
from langchain_community.embeddings import OllamaEmbeddings

llm_json_mode = ChatOllama(model="llama3.1:latest", format="json", temperature=0)
llm_generation = ChatOllama(model="llama3.1:latest", temperature=0)
embedding_engine = OllamaEmbeddings(model="nomic-embed-text:latest")  # 768 dims

# %% [markdown]
# **Sample format**
# ```json
# data_samples = {
#     'question': ['When was the first super bowl?', 'Who won the most super bowls?'],
#     'answer': ['The first superbowl was held on Jan 15, 1967', 'The most super bowls have been won by The New England Patriots'],
#     'contexts' : [['The First AFL–NFL World Championship Game was an American football game played on January 15, 1967, at the Los Angeles Memorial Coliseum in Los Angeles,'],
#     ['The Green Bay Packers...Green Bay, Wisconsin.','The Packers compete...Football Conference']],
#     'ground_truth': []
# }
# ```

# %%
def reformat_dataset(dataset):
    """Reformat the output from the eval set to match the expected format for RAGAS

    Args:
        dataset (_type_): _description_

    Returns:
        _type_: _description_
    """
    question = []
    answer = []
    contexts = []
    ground_truth = []
    for item in dataset:
        question.append(item.get('question'))
        answer.append(item.get('generated_answer'))
        contexts.append([" ".join(item.get('retrieved_docs'))])
        ground_truth.append(item.get('true_answer'))
    reformatted_dataset = {
        'question':question,
        'answer':answer,
        'contexts':contexts,
        'ground_truth':ground_truth
    }
    return reformatted_dataset

# %%
# Load the eval sets
import json
with open("agent_test.json") as f:
    agent_test = json.load(f)
    agent_test = reformat_dataset(agent_test)

with open("tfidf_test.json") as f:
    tfidf_test = json.load(f)
    tfidf_test = reformat_dataset(tfidf_test)


with open("faiss_test.json") as f:
    faiss_test = json.load(f)
    faiss_test = reformat_dataset(faiss_test)

with open("chroma_test.json") as f:
    chroma_test = json.load(f)
    chroma_test = reformat_dataset(chroma_test)

eval_set = {
    "agent_test": agent_test,
    "tfidf_test": tfidf_test,
    "chroma_test": chroma_test,
    "faiss_test": faiss_test,
}

# %%
from datasets import Dataset 
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    answer_similarity,
    context_precision,
    context_recall,
)
from ragas import evaluate


dataset = Dataset.from_dict(agent_test)
score = evaluate(dataset,metrics=[answer_relevancy, answer_similarity], llm=llm_json_mode, embeddings=embedding_engine)
score.to_pandas()
# Out:
# Evaluating:   0%|          | 0/50 [00:00<?, ?it/s]
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
# Failed to parse output. Returning None.
#                                              question  \
# 0   What type of camel was known to be an especial...
# 1   What are the standard ways to win a Random Map...
# 2   What types of units can Non-upgraded Monks con...
# 3   What military tradition did the Byzantine army...
# 4   What countries did the Normans invade besides ...
# 5   What impact did Viking sea raiders have on the...
# 6   In what state were Viking warriors known to en...
# 7   What shape were guard towers usually in the co...
# 8   What type of unit is created at the Stable in ...
# 9              What can move a Relic in this context?
# 10  How does building Mills, LumberCamps, or Minin...
# 11  What action does a Monk take once he has conve...
# 12  What structures and units can survive an attac...
# 13  Which religious groups embraced the practice o...
# 14  What determines the resistance of a unit to ot...
# 15  Which region did the Byzantine Empire lose dur...
# 16  What unique unit does the Persian create in Ca...
# 17  What was the main purpose of using skirmishers...
# 18  What did the Crusaders encounter when they inv...
# 19  What does a well-built stone wall offer protec...
# 20  What kind of information does the Statistics b...
# 21  What is a unique advantage of the camel in war...
# 22                  What are two roles of villagers??
# 23  How does a trade unit return gold in Cart or T...
# 24  What is one ability that improves the conversi...
#
#                                                answer  \
# 0   The heavy camel was known to be an especially ...
# 1   You can win a Random Map or Death Match game b...
# 2   Non-upgraded Monks can convert enemy villagers...
# 3   The Byzantine army carried on the military tra...
# 4   The Normans invaded Wales and Ireland in addit...
# 5   The Viking sea raiders disrupted the progress ...
# 6   Viking warriors were known to enter battle in ...
# 7   Guard towers were usually round in shape. This...
# 8   In Age of Empires 2, a Stable produces Cavalry...
# 9
# 10  Building Mills, LumberCamps, or Mining Camps n...
# 11  After converting a unit, a Monk stands idle un...
# 12  In the given context, the following structures...
# 13  Christianity and Buddhism embraced the practic...
# 14  Faith in the Monastery determines a unit's res...
# 15  The Byzantine Empire lost control of much of i...
# 16    The Persian creates War Elephant in Castle Age.
# 17  The main purpose of using skirmishers equipped...
# 18  The Crusaders encountered the ideas of Islam a...
# 19  A well-built stone wall offers protection agai...
# 20  The Statistics button displays the score for e...
# 21  The camel's ability to move quickly across san...
# 22  In Age of Empires 2, villagers can gather reso...
# 23  A trade unit returns gold to the Market or Doc...
# 24  The "Inferno" ability increases the conversion...
#
#                                              contexts  \
# 0   [The heavy camel was an especially experienced...
# 1   [16 Chapter II  -  Setting Up a GameHow to win...
# 2   [color) so you can control them. For example, ...
# 3   [Armor — Scale Barding Armor, Chain Barding Ar...
# 4   [invasion of 1066.  The Normans also invaded S...
# 5   [Late in the eighth century Viking sea raiders...
# 6   [Vikings were known for their great seamanship...
# 7   [for fighting defense. Whereas some earlier wa...
# 8   [you set a gather\npoint there while the units...
# 9                                                  []
# 10  [The more villagers at work gathering resource...
# 11  [must order a Monk to convert a unit. The Monk...
# 12  [must destroy all units and buildings but the ...
# 13  [53\nMonasteries were closed religious communi...
# 14  [Speed — Squires (Barracks)\nUnit creation spe...
# 15                                                 []
# 16  [78 Chapter VII  -  Units\nWar Elephant & Elit...
# 17  [bows,  slings, and javelins. The intent was t...
# 18  [invaded the Holy Lands,  for example, they en...
# 19  [Larger and more advanced civilizations upgrad...
# 20  [button above it and to the left.\nThe Statist...
# 21  [Barding Armor (Blacksmith)\nSpeed — Husbandry...
# 22  [and gold, hunt, forage, fish, herd sheep, and...
# 23  [Cart or Trade Cog returns to the Market or Do...
# 24  [HP — Sanctity\nConvert other Monks — Atonemen...
#
#                                          ground_truth  answer_relevancy  \
# 0   The heavy camel was an especially experienced ...          0.743739
# 1   You can win any Random Map or Death Match game...          0.000000
# 2   Non-upgraded Monks can convert enemy villagers...          0.831009
# 3   The Byzantine army carried on many of the mili...          0.773122
# 4   The Normans also invaded Sicily and southern I...          0.869014
# 5   The Vikings caused significant turmoil, which ...          0.792761
# 6   Viking warriors were known to enter a state of...          0.720605
# 7                    Guard towers were usually round.          0.825821
# 8                                             Cavalry          0.728853
# 9                A Relic can only be moved by a Monk.               NaN
# 10  Building Mills near sources of food, LumberCam...          0.755480
# 11  Once a Monk has converted a unit, he stands id...          0.000000
# 12  Towers, walls, gates, relics, Fishing Ships, F...          0.917652
# 13  Monastic life was embraced by several religion...          0.708645
# 14  The resistance of a unit to other Monks is det...          0.912806
# 15  The Byzantine Empire lost the plains of Asia M...          0.812196
# 16  The Persian creates a War Elephant in Castle Age.          0.689908
# 17  The main purpose of using skirmishers equipped...          0.859409
# 18  The Crusaders encountered the ideas of Islam, ...          0.900016
# 19  A well-built stone wall offers protection agai...          0.808596
# 20                          The score for each player          0.784797
# 21                 The camel can move quickly across.          0.864925
# 22  The two roles of villagers in this context are...          0.638835
# 23  A trade unit returns gold to locations owned b...          0.675741
# 24                                     Block Printing          0.562840
#
#     answer_similarity
# 0            0.934699
# 1            0.987623
# 2            0.995968
# 3            0.950230
# 4            0.858910
# 5            0.949424
# 6            0.927416
# 7            0.937901
# 8            0.837939
# 9            0.736023
# 10           0.967216
# 11           0.946656
# 12           0.861304
# 13           0.921769
# 14           0.981433
# 15           0.925893
# 16           0.997306
# 17           0.976641
# 18           0.943957
# 19           0.931961
# 20           0.843681
# 21           0.860212
# 22           0.798786
# 23           0.951042
# 24           0.593593

# %%
score
# Out:
# {'answer_relevancy': 0.7157, 'answer_similarity': 0.9047}

# %%
dataset_tfidf = Dataset.from_dict(tfidf_test)
score_tfidf = evaluate(dataset_tfidf, metrics=[
    answer_relevancy,
    answer_similarity,
], llm=llm_json_mode, embeddings=embedding_engine)
score_tfidf.to_pandas()
# Out:
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
#                                              question  \
# 0   What type of camel was known to be an especial...
# 1   What are the standard ways to win a Random Map...
# 2   What types of units can Non-upgraded Monks con...
# 3   What military tradition did the Byzantine army...
# 4   What countries did the Normans invade besides ...
# 5   What impact did Viking sea raiders have on the...
# 6   In what state were Viking warriors known to en...
# 7   What shape were guard towers usually in the co...
# 8   What type of unit is created at the Stable in ...
# 9              What can move a Relic in this context?
# 10  How does building Mills, LumberCamps, or Minin...
# 11  What action does a Monk take once he has conve...
# 12  What structures and units can survive an attac...
# 13  Which religious groups embraced the practice o...
# 14  What determines the resistance of a unit to ot...
# 15  Which region did the Byzantine Empire lose dur...
# 16  What unique unit does the Persian create in Ca...
# 17  What was the main purpose of using skirmishers...
# 18  What did the Crusaders encounter when they inv...
# 19  What does a well-built stone wall offer protec...
# 20  What kind of information does the Statistics b...
# 21  What is a unique advantage of the camel in war...
# 22                  What are two roles of villagers??
# 23  How does a trade unit return gold in Cart or T...
# 24  What is one ability that improves the conversi...
#
#                                                answer  \
# 0                          The Heavy Camel (page 78).
# 1   According to page 18, in a Random Map or Death...
# 2   Non-upgraded Monks can convert enemy buildings...
# 3   The Byzantine army carried on many of the mili...
# 4   According to page 86 of the context, the Norma...
# 5   The Viking sea raiders' raids for 150 years er...
# 6   They would go "berserk" and attack with nearly...
# 7   Guard towers were usually round (Extracted fro...
# 8                 Cavalry. \n\nExtracted from page 56
# 9                  A Monk (page 18) can move a relic.
# 10  According to page 28, building Mills near food...
# 11  Once a Monk converts a unit, it stands idle un...
# 12  According to the extracted text from page 60, ...
# 13  According to page 55, several religions, inclu...
# 14                                        Don't know.
# 15  The Byzantine Empire lost the plains of Asia M...
# 16  Unfortunately, there's no mention of a unique ...
# 17  The main purpose of using skirmishers equipped...
# 18  The Crusaders encountered new ideas of Islam, ...
# 19  A well-built stone wall offers protection agai...
# 20  If you have the Normal mini-map mode selected,...
# 21  The heavy camel was an experienced warrior and...
# 22  Two roles of villagers are: \n1. Garrisoning (...
# 23  A trade unit can only return gold to locations...
# 24                       Block Printing from page 90.
#
#                                              contexts  \
# 0   [The heavy camel was an especially experienced...
# 1   [Death Match game\nIn a Death Match, all playe...
# 2   [color) so you can control them. For example, ...
# 3   [Armor — Scale Barding Armor, Chain Barding Ar...
# 4   [The lord could withdraw into the tower, putti...
# 5   [Late in the eighth century Viking sea raiders...
# 6   [Vikings were known for their great seamanship...
# 7   [for fighting defense. Whereas some earlier wa...
# 8   [type of unit in the building)\nHold down CTRL...
# 9   [Chapter I: Getting Started\nWhat’s new in Age...
# 10  [The more villagers at work gathering resource...
# 11  [must order a Monk to convert a unit. The Monk...
# 12  [33Upgrading your units\nAs you advance throug...
# 13  [53\nMonasteries were closed religious communi...
# 14  [terminated. The map size determines how long ...
# 15  [The army was organized into formal units that...
# 16  [buildings. The Archery Range is used to creat...
# 17  [bows,  slings, and javelins. The intent was t...
# 18  [invaded the Holy Lands,  for example, they en...
# 19  [Larger and more advanced civilizations upgrad...
# 20  [button above it and to the left.\nThe Statist...
# 21  [Chapter I: Getting Started\nWhat’s new in Age...
# 22  [Chapter I: Getting Started\nWhat’s new in Age...
# 23  [To establish a trade route\n1 Build a Trade C...
# 24  [HP — Sanctity\nConvert other Monks — Atonemen...
#
#                                          ground_truth  answer_similarity
# 0   The heavy camel was an especially experienced ...           0.864201
# 1   You can win any Random Map or Death Match game...           0.976388
# 2   Non-upgraded Monks can convert enemy villagers...           0.947448
# 3   The Byzantine army carried on many of the mili...           0.972137
# 4   The Normans also invaded Sicily and southern I...           0.950800
# 5   The Vikings caused significant turmoil, which ...           0.931252
# 6   Viking warriors were known to enter a state of...           0.807066
# 7                    Guard towers were usually round.           0.933264
# 8                                             Cavalry           0.929457
# 9                A Relic can only be moved by a Monk.           0.939438
# 10  Building Mills near sources of food, LumberCam...           0.956434
# 11  Once a Monk has converted a unit, he stands id...           0.948928
# 12  Towers, walls, gates, relics, Fishing Ships, F...           0.713236
# 13  Monastic life was embraced by several religion...           0.938356
# 14  The resistance of a unit to other Monks is det...           0.587987
# 15  The Byzantine Empire lost the plains of Asia M...           0.911933
# 16  The Persian creates a War Elephant in Castle Age.           0.805084
# 17  The main purpose of using skirmishers equipped...           0.966743
# 18  The Crusaders encountered the ideas of Islam, ...           0.979031
# 19  A well-built stone wall offers protection agai...           0.982078
# 20                          The score for each player           0.856393
# 21                 The camel can move quickly across.           0.808191
# 22  The two roles of villagers in this context are...           0.823445
# 23  A trade unit returns gold to locations owned b...           0.960125
# 24                                     Block Printing           0.905280

# %%
score_tfidf
# Out:
# {'answer_similarity': 0.8958}

# %%
dataset_chroma = Dataset.from_dict(chroma_test)
score_chroma = evaluate(dataset_chroma, metrics=[
    answer_similarity,
], llm=llm_json_mode, embeddings=embedding_engine)
score_chroma.to_pandas()
# Out:
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
#                                              question  \
# 0   What type of camel was known to be an especial...
# 1   What are the standard ways to win a Random Map...
# 2   What types of units can Non-upgraded Monks con...
# 3   What military tradition did the Byzantine army...
# 4   What countries did the Normans invade besides ...
# 5   What impact did Viking sea raiders have on the...
# 6   In what state were Viking warriors known to en...
# 7   What shape were guard towers usually in the co...
# 8   What type of unit is created at the Stable in ...
# 9              What can move a Relic in this context?
# 10  How does building Mills, LumberCamps, or Minin...
# 11  What action does a Monk take once he has conve...
# 12  What structures and units can survive an attac...
# 13  Which religious groups embraced the practice o...
# 14  What determines the resistance of a unit to ot...
# 15  Which region did the Byzantine Empire lose dur...
# 16  What unique unit does the Persian create in Ca...
# 17  What was the main purpose of using skirmishers...
# 18  What did the Crusaders encounter when they inv...
# 19  What does a well-built stone wall offer protec...
# 20  What kind of information does the Statistics b...
# 21  What is a unique advantage of the camel in war...
# 22                  What are two roles of villagers??
# 23  How does a trade unit return gold in Cart or T...
# 24  What is one ability that improves the conversi...
#
#                                                answer  \
# 0             A heavy camel. (Extracted from page 78)
# 1   To win a Random Map or Death Match game, you c...
# 2   Non-upgraded Monks can convert most buildings,...
# 3   The Byzantine army carried on many of the mili...
# 4   According to the context (page 86), besides En...
# 5   The Viking raids erased most of the progress m...
# 6   Viking warriors would occasionally go "berserk...
# 7   Guard towers were usually round, as it elimina...
# 8   According to page 56, mounted warriors are cre...
# 9      According to page 90, a Monk can move a relic.
# 10  Building Mills, Lumber Camps, or Mining Camps ...
# 11  A Monk stands idle until given another command...
# 12  According to the extracted text from page 36, ...
# 13  Christianity and Buddhism were among the relig...
# 14  According to the context (page 62), a unit's r...
# 15  I'm not sure. The context doesn't specify that...
# 16  The Persian creates a War Elephant and an Elit...
# 17  The main purpose of using skirmishers equipped...
# 18  When the Crusaders invaded the Holy Lands, the...
# 19  A well-built stone wall offers protection agai...
# 20  If the Normal mini-map mode is selected, the s...
# 21  A unique advantage of camels in warfare is the...
# 22  Two roles of villagers are:\n\n1. Gathering re...
# 23  A trade unit returns gold to locations owned b...
# 24                          Block Printing (page 90).
#
#                                              contexts  \
# 0   [The heavy camel was an especially experienced...
# 1   [the game. You can display the objectives agai...
# 2   [You can convert and use a building you have n...
# 3   [Armor — Scale Barding Armor, Chain Barding Ar...
# 4   [invasion of 1066.  The Normans also invaded S...
# 5   [Late in the eighth century Viking sea raiders...
# 6   [Vikings were known for their great seamanship...
# 7   [for fighting defense. Whereas some earlier wa...
# 8   [type of unit in the building)\nHold down CTRL...
# 9   [are special objects (similar to trophies) tha...
# 10  [Constructing buildings\nVillagers can deposit...
# 11  [must order a Monk to convert a unit. The Monk...
# 12  [strength of a Castle or tower with garrisoned...
# 13  [53\nMonasteries were closed religious communi...
# 14  [To convert an enemy unit or building\nClick a...
# 15  [Armor — Careening (Dock)\nSpeed — Dry Dock (D...
# 16  [engine. Several important military technologi...
# 17  [bows,  slings, and javelins. The intent was t...
# 18  [invaded the Holy Lands,  for example, they en...
# 19  [Larger and more advanced civilizations upgrad...
# 20  [button above it and to the left.\nThe Statist...
# 21  [The heavy camel was an especially experienced...
# 22  [and gold, hunt, forage, fish, herd sheep, and...
# 23  [Cart or Trade Cog returns to the Market or Do...
# 24  [To convert an enemy unit or building\nClick a...
#
#                                          ground_truth  answer_similarity
# 0   The heavy camel was an especially experienced ...           0.864825
# 1   You can win any Random Map or Death Match game...           0.975089
# 2   Non-upgraded Monks can convert enemy villagers...           0.963749
# 3   The Byzantine army carried on many of the mili...           0.972142
# 4   The Normans also invaded Sicily and southern I...           0.951751
# 5   The Vikings caused significant turmoil, which ...           0.949386
# 6   Viking warriors were known to enter a state of...           0.955507
# 7                    Guard towers were usually round.           0.923923
# 8                                             Cavalry           0.806100
# 9                A Relic can only be moved by a Monk.           0.950778
# 10  Building Mills near sources of food, LumberCam...           0.953670
# 11  Once a Monk has converted a unit, he stands id...           0.899737
# 12  Towers, walls, gates, relics, Fishing Ships, F...           0.889501
# 13  Monastic life was embraced by several religion...           0.927849
# 14  The resistance of a unit to other Monks is det...           0.970346
# 15  The Byzantine Empire lost the plains of Asia M...           0.596790
# 16  The Persian creates a War Elephant in Castle Age.           0.950852
# 17  The main purpose of using skirmishers equipped...           0.966745
# 18  The Crusaders encountered the ideas of Islam, ...           0.926194
# 19  A well-built stone wall offers protection agai...           0.947535
# 20                          The score for each player           0.858820
# 21                 The camel can move quickly across.           0.865310
# 22  The two roles of villagers in this context are...           0.856739
# 23  A trade unit returns gold to locations owned b...           0.948030
# 24                                     Block Printing           0.949635

# %%
score_chroma
# Out:
# {'answer_similarity': 0.9128}

# %%
dataset_faiss = Dataset.from_dict(faiss_test)
score_faiss = evaluate(dataset_faiss, metrics=[
    answer_similarity,
], llm=llm_json_mode, embeddings=embedding_engine)
score_faiss.to_pandas()
# Out:
# Evaluating:   0%|          | 0/25 [00:00<?, ?it/s]
#                                              question  \
# 0   What type of camel was known to be an especial...
# 1   What are the standard ways to win a Random Map...
# 2   What types of units can Non-upgraded Monks con...
# 3   What military tradition did the Byzantine army...
# 4   What countries did the Normans invade besides ...
# 5   What impact did Viking sea raiders have on the...
# 6   In what state were Viking warriors known to en...
# 7   What shape were guard towers usually in the co...
# 8   What type of unit is created at the Stable in ...
# 9              What can move a Relic in this context?
# 10  How does building Mills, LumberCamps, or Minin...
# 11  What action does a Monk take once he has conve...
# 12  What structures and units can survive an attac...
# 13  Which religious groups embraced the practice o...
# 14  What determines the resistance of a unit to ot...
# 15  Which region did the Byzantine Empire lose dur...
# 16  What unique unit does the Persian create in Ca...
# 17  What was the main purpose of using skirmishers...
# 18  What did the Crusaders encounter when they inv...
# 19  What does a well-built stone wall offer protec...
# 20  What kind of information does the Statistics b...
# 21  What is a unique advantage of the camel in war...
# 22                  What are two roles of villagers??
# 23  How does a trade unit return gold in Cart or T...
# 24  What is one ability that improves the conversi...
#
#                                                answer  \
# 0   According to Context from page 78, the "Heavy ...
# 1   To win a Random Map or Death Match game in Age...
# 2   Non-upgraded Monks can convert most buildings ...
# 3   The Byzantine army carried on many of the mili...
# 4   According to page 86 of the extracted text, th...
# 5   The Viking sea raiders caused most of the prog...
# 6   Viking warriors would occasionally go "berserk...
# 7   Guard towers were usually round. (Extracted fr...
# 8   According to page 56, horses are bred and main...
# 9                  A Monk can move a relic. (Page 18)
# 10  According to page 27: "The more villagers at w...
# 11  A Monk stands idle until given another command...
# 12  According to the context from page 36, the fol...
# 13  Christianity (page 53) and Buddhism (page 53) ...
# 14  It's determined by "Faith" researched at the M...
# 15  The Byzantine Empire lost the plains of Asia M...
# 16  According to the extracted text from page 80, ...
# 17  The main purpose of using skirmishers equipped...
# 18  When the Crusaders invaded the Holy Land, they...
# 19  A well-built stone wall offers protection agai...
# 20  The score for each player appears on the Stati...
# 21  According to extracted from page 78, a unique ...
# 22  According to page 26, two roles of villagers a...
# 23  A trade unit returns gold to locations owned b...
# 24                          Block Printing. (Page 90)
#
#                                              contexts  \
# 0   [The heavy camel was an especially experienced...
# 1   [the game. You can display the objectives agai...
# 2   [You can convert and use a building you have n...
# 3   [Armor — Scale Barding Armor, Chain Barding Ar...
# 4   [invasion of 1066.  The Normans also invaded S...
# 5   [Late in the eighth century Viking sea raiders...
# 6   [Vikings were known for their great seamanship...
# 7   [for fighting defense. Whereas some earlier wa...
# 8   [type of unit in the building)\nHold down CTRL...
# 9   [are special objects (similar to trophies) tha...
# 10  [Constructing buildings\nVillagers can deposit...
# 11  [must order a Monk to convert a unit. The Monk...
# 12  [strength of a Castle or tower with garrisoned...
# 13  [53\nMonasteries were closed religious communi...
# 14  [To convert an enemy unit or building\nClick a...
# 15  [decline partially because it lost the plains ...
# 16  [engine. Several important military technologi...
# 17  [bows,  slings, and javelins. The intent was t...
# 18  [invaded the Holy Lands,  for example, they en...
# 19  [Larger and more advanced civilizations upgrad...
# 20  [button above it and to the left.\nThe Statist...
# 21  [The heavy camel was an especially experienced...
# 22  [and gold, hunt, forage, fish, herd sheep, and...
# 23  [Cart or Trade Cog returns to the Market or Do...
# 24  [To convert an enemy unit or building\nClick a...
#
#                                          ground_truth  answer_similarity
# 0   The heavy camel was an especially experienced ...           0.963969
# 1   You can win any Random Map or Death Match game...           0.915963
# 2   Non-upgraded Monks can convert enemy villagers...           0.951167
# 3   The Byzantine army carried on many of the mili...           0.977842
# 4   The Normans also invaded Sicily and southern I...           0.956800
# 5   The Vikings caused significant turmoil, which ...           0.942184
# 6   Viking warriors were known to enter a state of...           0.955511
# 7                    Guard towers were usually round.           0.956817
# 8                                             Cavalry           0.781255
# 9                A Relic can only be moved by a Monk.           0.935338
# 10  Building Mills near sources of food, LumberCam...           0.925567
# 11  Once a Monk has converted a unit, he stands id...           0.961435
# 12  Towers, walls, gates, relics, Fishing Ships, F...           0.886346
# 13  Monastic life was embraced by several religion...           0.943115
# 14  The resistance of a unit to other Monks is det...           0.869583
# 15  The Byzantine Empire lost the plains of Asia M...           0.912347
# 16  The Persian creates a War Elephant in Castle Age.           0.935951
# 17  The main purpose of using skirmishers equipped...           0.977268
# 18  The Crusaders encountered the ideas of Islam, ...           0.953340
# 19  A well-built stone wall offers protection agai...           0.937103
# 20                          The score for each player           0.855995
# 21                 The camel can move quickly across.           0.818740
# 22  The two roles of villagers in this context are...           0.860813
# 23  A trade unit returns gold to locations owned b...           0.937035
# 24                                     Block Printing           0.956242

# %%
score_faiss
# Out:
# {'answer_similarity': 0.9227}
